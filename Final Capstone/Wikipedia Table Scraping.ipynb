# %% [markdown]
# <h2><u> Part 1: Finding the shape of the pre-processed table </u></h2>

# %%
import requests
from scrapy.http import TextResponse
from bs4 import BeautifulSoup
import re 
import pandas as pd

# %% [markdown]
# <h3> Functions used to parse a website, remove html tags and remove special chars like \n</h3>

# %%
#parses web link and returns matches found for given tag
def parser(link, tag):
    res = requests.get(link)
    response = TextResponse(res.url, body=res.text, encoding='utf-8')
    return response.css(tag).getall()
    
#function to remove html tags
def remove_html(movies):
    sol = []
    for movie in movies:
        s = BeautifulSoup(movie, "lxml").text
        if re.search('[a-zA-Z]', s):
            sol.append(s)
    return sol

#function to remove dates and special chars
def remove_non_chars(movies):
    regex = re.compile('[^a-z : - A-Z]')
    for idx, movie in enumerate(movies):
        movies[idx] = regex.sub('', movie)
    return movies

# %% [markdown]
# <h3> Parse the website, remove html tags and special chars </h3>

# %%
link = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
tag = 'td'
table = parser(link, tag)
#removed the data outside of the table and remove the html tags scraped 
table = remove_html(table[:-34])
table = remove_non_chars(table)

# %% [markdown]
# <h3> Create the pandas dataframe by first grouping every 3 values together in a nested list and then converting it into a pandas dataframe </h3>

# %%
#grouping every 3 values a single list inside a list
#easier to make this list and to then append it into a pandas dataframe!
i = 3
lis = []
while i <= len(table):
    lis.append(table[i-3:i])
    i += 3
lis
# Out:
# [['MA', 'Not assigned', 'Not assigned'],
#  ['MA', 'Not assigned', 'Not assigned'],
#  ['MA', 'North York', 'Parkwoods'],
#  ['MA', 'North York', 'Victoria Village'],
#  ['MA', 'Downtown Toronto', 'Harbourfront'],
#  ['MA', 'North York', 'Lawrence Heights'],
#  ['MA', 'North York', 'Lawrence Manor'],
#  ['MA', 'Downtown Toronto', 'Queens Park'],
#  ['MA', 'Not assigned', 'Not assigned'],
#  ['MA', 'Queens Park', 'Not assigned'],
#  ['MB', 'Scarborough', 'Rouge'],
#  ['MB', 'Scarborough', 'Malvern'],
#  ['MB', 'Not assigned', 'Not assigned'],
#  ['MB', 'North York', 'Don Mills North'],
#  ['MB', 'East York', 'Woodbine Gardens'],
#  ['MB', 'East York', 'Parkview Hill'],
#  ['MB', 'Downtown Toronto', 'Ryerson'],
#  ['MB', 'Downtown Toronto', 'Garden District'],
#  ['MB', 'North York', 'Glencairn'],
#  ['MB', 'Not assigned', 'Not assigned'],
#  ['MB', 'Not assigned', 'Not assigned'],
#  ['MB', 'Etobicoke', 'Cloverdale'],
#  ['MB', 'Etobicoke', 'Islington'],
#  ['MB', 'Etobicoke', 'Martin Grove'],
#  ['MB', 'Etobicoke', 'Princess Gardens'],
#  ['MB', 'Etobicoke', 'West Deane Park'],
#  ['MC', 'Scarborough', 'Highland Creek'],
#  ['MC', 'Scarborough', 'Rouge Hill'],
#  ['MC', 'Scarborough', 'Port Union'],
#  ['MC', 'Not assigned', 'Not assigned'],
#  ['MC', 'North York', 'Flemingdon Park'],
#  ['MC', 'North York', 'Don Mills South'],
#  ['MC', 'East York', 'Woodbine Heights'],
#  ['MC', 'Downtown Toronto', 'St James Town'],
#  ['MC', 'York', 'HumewoodCedarvale'],
#  ['MC', 'Not assigned', 'Not assigned'],
#  ['MC', 'Not assigned', 'Not assigned'],
#  ['MC', 'Etobicoke', 'Bloordale Gardens'],
#  ['MC', 'Etobicoke', 'Eringate'],
#  ['MC', 'Etobicoke', 'Markland Wood'],
#  ['MC', 'Etobicoke', 'Old Burnhamthorpe'],
#  ['ME', 'Scarborough', 'Guildwood'],
#  ['ME', 'Scarborough', 'Morningside'],
#  ['ME', 'Scarborough', 'West Hill'],
#  ['ME', 'Not assigned', 'Not assigned'],
#  ['ME', 'Not assigned', 'Not assigned'],
#  ['ME', 'East Toronto', 'The Beaches'],
#  ['ME', 'Downtown Toronto', 'Berczy Park'],
#  ['ME', 'York', 'CaledoniaFairbanks'],
#  ['ME', 'Not assigned', 'Not assigned'],
#  ['ME', 'Not assigned', 'Not assigned'],
#  ['ME', 'Not assigned', 'Not assigned'],
#  ['MG', 'Scarborough', 'Woburn'],
#  ['MG', 'Not assigned', 'Not assigned'],
#  ['MG', 'Not assigned', 'Not assigned'],
#  ['MG', 'East York', 'Leaside'],
#  ['MG', 'Downtown Toronto', 'Central Bay Street'],
#  ['MG', 'Downtown Toronto', 'Christie'],
#  ['MG', 'Not assigned', 'Not assigned'],
#  ['MG', 'Not assigned', 'Not assigned'],
#  ['MG', 'Not assigned', 'Not assigned'],
#  ['MH', 'Scarborough', 'Cedarbrae'],
#  ['MH', 'North York', 'Hillcrest Village'],
#  ['MH', 'North York', 'Bathurst Manor'],
#  ['MH', 'North York', 'Downsview North'],
#  ['MH', 'North York', 'Wilson Heights'],
#  ['MH', 'East York', 'Thorncliffe Park'],
#  ['MH', 'Downtown Toronto', 'Adelaide'],
#  ['MH', 'Downtown Toronto', 'King'],
#  ['MH', 'Downtown Toronto', 'Richmond'],
#  ['MH', 'West Toronto', 'Dovercourt Village'],
#  ['MH', 'West Toronto', 'Dufferin'],
#  ['MH', 'Not assigned', 'Not assigned'],
#  ['MH', 'Not assigned', 'Not assigned'],
#  ['MH', 'Not assigned', 'Not assigned'],
#  ['MJ', 'Scarborough', 'Scarborough Village'],
#  ['MJ', 'North York', 'Fairview'],
#  ['MJ', 'North York', 'Henry Farm'],
#  ['MJ', 'North York', 'Oriole'],
#  ['MJ', 'North York', 'Northwood Park'],
#  ['MJ', 'North York', 'York University'],
#  ['MJ', 'East York', 'East Toronto'],
#  ['MJ', 'Downtown Toronto', 'Harbourfront East'],
#  ['MJ', 'Downtown Toronto', 'Toronto Islands'],
#  ['MJ', 'Downtown Toronto', 'Union Station'],
#  ['MJ', 'West Toronto', 'Little Portugal'],
#  ['MJ', 'West Toronto', 'Trinity'],
#  ['MJ', 'Not assigned', 'Not assigned'],
#  ['MJ', 'Not assigned', 'Not assigned'],
#  ['MJ', 'Not assigned', 'Not assigned'],
#  ['MK', 'Scarborough', 'East Birchmount Park'],
#  ['MK', 'Scarborough', 'Ionview'],
#  ['MK', 'Scarborough', 'Kennedy Park'],
#  ['MK', 'North York', 'Bayview Village'],
#  ['MK', 'North York', 'CFB Toronto'],
#  ['MK', 'North York', 'Downsview East'],
#  ['MK', 'East Toronto', 'The Danforth West'],
#  ['MK', 'East Toronto', 'Riverdale'],
#  ['MK', 'Downtown Toronto', 'Design Exchange'],
#  ['MK', 'Downtown Toronto', 'Toronto Dominion Centre'],
#  ['MK', 'West Toronto', 'Brockton'],
#  ['MK', 'West Toronto', 'Exhibition Place'],
#  ['MK', 'West Toronto', 'Parkdale Village'],
#  ['MK', 'Not assigned', 'Not assigned'],
#  ['MK', 'Not assigned', 'Not assigned'],
#  ['MK', 'Not assigned', 'Not assigned'],
#  ['ML', 'Scarborough', 'Clairlea'],
#  ['ML', 'Scarborough', 'Golden Mile'],
#  ['ML', 'Scarborough', 'Oakridge'],
#  ['ML', 'North York', 'Silver Hills'],
#  ['ML', 'North York', 'York Mills'],
#  ['ML', 'North York', 'Downsview West'],
#  ['ML', 'East Toronto', 'The Beaches West'],
#  ['ML', 'East Toronto', 'India Bazaar'],
#  ['ML', 'Downtown Toronto', 'Commerce Court'],
#  ['ML', 'Downtown Toronto', 'Victoria Hotel'],
#  ['ML', 'North York', 'Downsview'],
#  ['ML', 'North York', 'North Park'],
#  ['ML', 'North York', 'Upwood Park'],
#  ['ML', 'Not assigned', 'Not assigned'],
#  ['ML', 'Not assigned', 'Not assigned'],
#  ['ML', 'North York', 'Humber Summit'],
#  ['MM', 'Scarborough', 'Cliffcrest'],
#  ['MM', 'Scarborough', 'Cliffside'],
#  ['MM', 'Scarborough', 'Scarborough Village West'],
#  ['MM', 'North York', 'Newtonbrook'],
#  ['MM', 'North York', 'Willowdale'],
#  ['MM', 'North York', 'Downsview Central'],
#  ['MM', 'East Toronto', 'Studio District'],
#  ['MM', 'North York', 'Bedford Park'],
#  ['MM', 'North York', 'Lawrence Manor East'],
#  ['MM', 'York', 'Del Ray'],
#  ['MM', 'York', 'Keelesdale'],
#  ['MM', 'York', 'Mount Dennis'],
#  ['MM', 'York', 'Silverthorn'],
#  ['MM', 'Not assigned', 'Not assigned'],
#  ['MM', 'Not assigned', 'Not assigned'],
#  ['MM', 'North York', 'Emery'],
#  ['MM', 'North York', 'Humberlea'],
#  ['MN', 'Scarborough', 'Birch Cliff'],
#  ['MN', 'Scarborough', 'Cliffside West'],
#  ['MN', 'North York', 'Willowdale South'],
#  ['MN', 'North York', 'Downsview Northwest'],
#  ['MN', 'Central Toronto', 'Lawrence Park'],
#  ['MN', 'Central Toronto', 'Roselawn'],
#  ['MN', 'York', 'The Junction North'],
#  ['MN', 'York', 'Runnymede'],
#  ['MN', 'Not assigned', 'Not assigned'],
#  ['MN', 'Not assigned', 'Not assigned'],
#  ['MN', 'York', 'Weston'],
#  ['MP', 'Scarborough', 'Dorset Park'],
#  ['MP', 'Scarborough', 'Scarborough Town Centre'],
#  ['MP', 'Scarborough', 'Wexford Heights'],
#  ['MP', 'North York', 'York Mills West'],
#  ['MP', 'Not assigned', 'Not assigned'],
#  ['MP', 'Central Toronto', 'Davisville North'],
#  ['MP', 'Central Toronto', 'Forest Hill North'],
#  ['MP', 'Central Toronto', 'Forest Hill West'],
#  ['MP', 'West Toronto', 'High Park'],
#  ['MP', 'West Toronto', 'The Junction South'],
#  ['MP', 'Not assigned', 'Not assigned'],
#  ['MP', 'Not assigned', 'Not assigned'],
#  ['MP', 'Etobicoke', 'Westmount'],
#  ['MR', 'Scarborough', 'Maryvale'],
#  ['MR', 'Scarborough', 'Wexford'],
#  ['MR', 'North York', 'Willowdale West'],
#  ['MR', 'Not assigned', 'Not assigned'],
#  ['MR', 'Central Toronto', 'North Toronto West'],
#  ['MR', 'Central Toronto', 'The Annex'],
#  ['MR', 'Central Toronto', 'North Midtown'],
#  ['MR', 'Central Toronto', 'Yorkville'],
#  ['MR', 'West Toronto', 'Parkdale'],
#  ['MR', 'West Toronto', 'Roncesvalles'],
#  ['MR', 'Mississauga', 'Canada Post Gateway Processing Centre'],
#  ['MR', 'Not assigned', 'Not assigned'],
#  ['MR', 'Etobicoke', 'Kingsview Village'],
#  ['MR', 'Etobicoke', 'Martin Grove Gardens'],
#  ['MR', 'Etobicoke', 'Richview Gardens'],
#  ['MR', 'Etobicoke', 'St Phillips'],
#  ['MS', 'Scarborough', 'Agincourt'],
#  ['MS', 'Not assigned', 'Not assigned'],
#  ['MS', 'Not assigned', 'Not assigned'],
#  ['MS', 'Central Toronto', 'Davisville'],
#  ['MS', 'Downtown Toronto', 'Harbord'],
#  ['MS', 'Downtown Toronto', 'University of Toronto'],
#  ['MS', 'West Toronto', 'Runnymede'],
#  ['MS', 'West Toronto', 'Swansea'],
#  ['MS', 'Not assigned', 'Not assigned'],
#  ['MS', 'Not assigned', 'Not assigned'],
#  ['MS', 'Not assigned', 'Not assigned'],
#  ['MT', 'Scarborough', 'Clarks Corners'],
#  ['MT', 'Scarborough', 'Sullivan'],
#  ['MT', 'Scarborough', 'Tam OShanter'],
#  ['MT', 'Not assigned', 'Not assigned'],
#  ['MT', 'Not assigned', 'Not assigned'],
#  ['MT', 'Central Toronto', 'Moore Park'],
#  ['MT', 'Central Toronto', 'Summerhill East'],
#  ['MT', 'Downtown Toronto', 'Chinatown'],
#  ['MT', 'Downtown Toronto', 'Grange Park'],
#  ['MT', 'Downtown Toronto', 'Kensington Market'],
#  ['MT', 'Not assigned', 'Not assigned'],
#  ['MT', 'Not assigned', 'Not assigned'],
#  ['MT', 'Not assigned', 'Not assigned'],
#  ['MT', 'Not assigned', 'Not assigned'],
#  ['MV', 'Scarborough', 'Agincourt North'],
#  ['MV', 'Scarborough', 'LAmoreaux East'],
#  ['MV', 'Scarborough', 'Milliken'],
#  ['MV', 'Scarborough', 'Steeles East'],
#  ['MV', 'Not assigned', 'Not assigned'],
#  ['MV', 'Not assigned', 'Not assigned'],
#  ['MV', 'Central Toronto', 'Deer Park'],
#  ['MV', 'Central Toronto', 'Forest Hill SE'],
#  ['MV', 'Central Toronto', 'Rathnelly'],
#  ['MV', 'Central Toronto', 'South Hill'],
#  ['MV', 'Central Toronto', 'Summerhill West'],
#  ['MV', 'Downtown Toronto', 'CN Tower'],
#  ['MV', 'Downtown Toronto', 'Bathurst Quay'],
#  ['MV', 'Downtown Toronto', 'Island airport'],
#  ['MV', 'Downtown Toronto', 'Harbourfront West'],
#  ['MV', 'Downtown Toronto', 'King and Spadina'],
#  ['MV', 'Downtown Toronto', 'Railway Lands'],
#  ['MV', 'Downtown Toronto', 'South Niagara'],
#  ['MV', 'Not assigned', 'Not assigned'],
#  ['MV', 'Not assigned', 'Not assigned'],
#  ['MV', 'Etobicoke', 'Humber Bay Shores'],
#  ['MV', 'Etobicoke', 'Mimico South'],
#  ['MV', 'Etobicoke', 'New Toronto'],
#  ['MV', 'Etobicoke', 'Albion Gardens'],
#  ['MV', 'Etobicoke', 'Beaumond Heights'],
#  ['MV', 'Etobicoke', 'Humbergate'],
#  ['MV', 'Etobicoke', 'Jamestown'],
#  ['MV', 'Etobicoke', 'Mount Olive'],
#  ['MV', 'Etobicoke', 'Silverstone'],
#  ['MV', 'Etobicoke', 'South Steeles'],
#  ['MV', 'Etobicoke', 'Thistletown'],
#  ['MW', 'Scarborough', 'LAmoreaux West'],
#  ['MW', 'Not assigned', 'Not assigned'],
#  ['MW', 'Not assigned', 'Not assigned'],
#  ['MW', 'Downtown Toronto', 'Rosedale'],
#  ['MW', 'Downtown Toronto', 'Stn A PO Boxes  The Esplanade'],
#  ['MW', 'Not assigned', 'Not assigned'],
#  ['MW', 'Not assigned', 'Not assigned'],
#  ['MW', 'Etobicoke', 'Alderwood'],
#  ['MW', 'Etobicoke', 'Long Branch'],
#  ['MW', 'Etobicoke', 'Northwest'],
#  ['MX', 'Scarborough', 'Upper Rouge'],
#  ['MX', 'Not assigned', 'Not assigned'],
#  ['MX', 'Not assigned', 'Not assigned'],
#  ['MX', 'Downtown Toronto', 'Cabbagetown'],
#  ['MX', 'Downtown Toronto', 'St James Town'],
#  ['MX', 'Downtown Toronto', 'First Canadian Place'],
#  ['MX', 'Downtown Toronto', 'Underground city'],
#  ['MX', 'Not assigned', 'Not assigned'],
#  ['MX', 'Not assigned', 'Not assigned'],
#  ['MX', 'Etobicoke', 'The Kingsway'],
#  ['MX', 'Etobicoke', 'Montgomery Road'],
#  ['MX', 'Etobicoke', 'Old Mill North'],
#  ['MX', 'Not assigned', 'Not assigned'],
#  ['MY', 'Not assigned', 'Not assigned'],
#  ['MY', 'Not assigned', 'Not assigned'],
#  ['MY', 'Not assigned', 'Not assigned'],
#  ['MY', 'Downtown Toronto', 'Church and Wellesley'],
#  ['MY', 'Not assigned', 'Not assigned'],
#  ['MY', 'Not assigned', 'Not assigned'],
#  ['MY', 'East Toronto', 'Business Reply Mail Processing Centre  Eastern'],
#  ['MY', 'Etobicoke', 'Humber Bay'],
#  ['MY', 'Etobicoke', 'Kings Mill Park'],
#  ['MY', 'Etobicoke', 'Kingsway Park South East'],
#  ['MY', 'Etobicoke', 'Mimico NE'],
#  ['MY', 'Etobicoke', 'Old Mill South'],
#  ['MY', 'Etobicoke', 'The Queensway East'],
#  ['MY', 'Etobicoke', 'Royal York South East'],
#  ['MY', 'Etobicoke', 'Sunnylea'],
#  ['MY', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Not assigned', 'Not assigned'],
#  ['MZ', 'Etobicoke', 'Kingsway Park South West'],
#  ['MZ', 'Etobicoke', 'Mimico NW'],
#  ['MZ', 'Etobicoke', 'The Queensway West'],
#  ['MZ', 'Etobicoke', 'Royal York South West'],
#  ['MZ', 'Etobicoke', 'South of Bloor'],
#  ['MZ', 'Not assigned', 'Not assigned']]

# %%
#every 3 values needs to be inserted into a pandas dataframe to make the final table
df = pd.DataFrame(lis, columns = ['PostalCode', 'Borough', 'Neighborhood'])
df
# Out:
#     PostalCode           Borough  \
# 0           MA      Not assigned
# 1           MA      Not assigned
# 2           MA        North York
# 3           MA        North York
# 4           MA  Downtown Toronto
# 5           MA        North York
# 6           MA        North York
# 7           MA  Downtown Toronto
# 8           MA      Not assigned
# 9           MA       Queens Park
# 10          MB       Scarborough
# 11          MB       Scarborough
# 12          MB      Not assigned
# 13          MB        North York
# 14          MB         East York
# 15          MB         East York
# 16          MB  Downtown Toronto
# 17          MB  Downtown Toronto
# 18          MB        North York
# 19          MB      Not assigned
# 20          MB      Not assigned
# 21          MB         Etobicoke
# 22          MB         Etobicoke
# 23          MB         Etobicoke
# 24          MB         Etobicoke
# 25          MB         Etobicoke
# 26          MC       Scarborough
# 27          MC       Scarborough
# 28          MC       Scarborough
# 29          MC      Not assigned
# ..         ...               ...
# 257         MX      Not assigned
# 258         MY      Not assigned
# 259         MY      Not assigned
# 260         MY      Not assigned
# 261         MY  Downtown Toronto
# 262         MY      Not assigned
# 263         MY      Not assigned
# 264         MY      East Toronto
# 265         MY         Etobicoke
# 266         MY         Etobicoke
# 267         MY         Etobicoke
# 268         MY         Etobicoke
# 269         MY         Etobicoke
# 270         MY         Etobicoke
# 271         MY         Etobicoke
# 272         MY         Etobicoke
# 273         MY      Not assigned
# 274         MZ      Not assigned
# 275         MZ      Not assigned
# 276         MZ      Not assigned
# 277         MZ      Not assigned
# 278         MZ      Not assigned
# 279         MZ      Not assigned
# 280         MZ      Not assigned
# 281         MZ         Etobicoke
# 282         MZ         Etobicoke
# 283         MZ         Etobicoke
# 284         MZ         Etobicoke
# 285         MZ         Etobicoke
# 286         MZ      Not assigned
#
#                                        Neighborhood
# 0                                      Not assigned
# 1                                      Not assigned
# 2                                         Parkwoods
# 3                                  Victoria Village
# 4                                      Harbourfront
# 5                                  Lawrence Heights
# 6                                    Lawrence Manor
# 7                                       Queens Park
# 8                                      Not assigned
# 9                                      Not assigned
# 10                                            Rouge
# 11                                          Malvern
# 12                                     Not assigned
# 13                                  Don Mills North
# 14                                 Woodbine Gardens
# 15                                    Parkview Hill
# 16                                          Ryerson
# 17                                  Garden District
# 18                                        Glencairn
# 19                                     Not assigned
# 20                                     Not assigned
# 21                                       Cloverdale
# 22                                        Islington
# 23                                     Martin Grove
# 24                                 Princess Gardens
# 25                                  West Deane Park
# 26                                   Highland Creek
# 27                                       Rouge Hill
# 28                                       Port Union
# 29                                     Not assigned
# ..                                              ...
# 257                                    Not assigned
# 258                                    Not assigned
# 259                                    Not assigned
# 260                                    Not assigned
# 261                            Church and Wellesley
# 262                                    Not assigned
# 263                                    Not assigned
# 264  Business Reply Mail Processing Centre  Eastern
# 265                                      Humber Bay
# 266                                 Kings Mill Park
# 267                        Kingsway Park South East
# 268                                       Mimico NE
# 269                                  Old Mill South
# 270                              The Queensway East
# 271                           Royal York South East
# 272                                        Sunnylea
# 273                                    Not assigned
# 274                                    Not assigned
# 275                                    Not assigned
# 276                                    Not assigned
# 277                                    Not assigned
# 278                                    Not assigned
# 279                                    Not assigned
# 280                                    Not assigned
# 281                        Kingsway Park South West
# 282                                       Mimico NW
# 283                              The Queensway West
# 284                           Royal York South West
# 285                                  South of Bloor
# 286                                    Not assigned
#
# [287 rows x 3 columns]

# %% [markdown]
# <h3> Here I drop the not assigned boroughs and reset the index </h3>

# %%
#drop cells with not assigned borough
df = df[df.Borough != 'Not assigned']
df.reset_index(drop = True, inplace = True)
df
# Out:
#     PostalCode           Borough  \
# 0           MA        North York
# 1           MA        North York
# 2           MA  Downtown Toronto
# 3           MA        North York
# 4           MA        North York
# 5           MA  Downtown Toronto
# 6           MA       Queens Park
# 7           MB       Scarborough
# 8           MB       Scarborough
# 9           MB        North York
# 10          MB         East York
# 11          MB         East York
# 12          MB  Downtown Toronto
# 13          MB  Downtown Toronto
# 14          MB        North York
# 15          MB         Etobicoke
# 16          MB         Etobicoke
# 17          MB         Etobicoke
# 18          MB         Etobicoke
# 19          MB         Etobicoke
# 20          MC       Scarborough
# 21          MC       Scarborough
# 22          MC       Scarborough
# 23          MC        North York
# 24          MC        North York
# 25          MC         East York
# 26          MC  Downtown Toronto
# 27          MC              York
# 28          MC         Etobicoke
# 29          MC         Etobicoke
# ..         ...               ...
# 180         MV         Etobicoke
# 181         MW       Scarborough
# 182         MW  Downtown Toronto
# 183         MW  Downtown Toronto
# 184         MW         Etobicoke
# 185         MW         Etobicoke
# 186         MW         Etobicoke
# 187         MX       Scarborough
# 188         MX  Downtown Toronto
# 189         MX  Downtown Toronto
# 190         MX  Downtown Toronto
# 191         MX  Downtown Toronto
# 192         MX         Etobicoke
# 193         MX         Etobicoke
# 194         MX         Etobicoke
# 195         MY  Downtown Toronto
# 196         MY      East Toronto
# 197         MY         Etobicoke
# 198         MY         Etobicoke
# 199         MY         Etobicoke
# 200         MY         Etobicoke
# 201         MY         Etobicoke
# 202         MY         Etobicoke
# 203         MY         Etobicoke
# 204         MY         Etobicoke
# 205         MZ         Etobicoke
# 206         MZ         Etobicoke
# 207         MZ         Etobicoke
# 208         MZ         Etobicoke
# 209         MZ         Etobicoke
#
#                                        Neighborhood
# 0                                         Parkwoods
# 1                                  Victoria Village
# 2                                      Harbourfront
# 3                                  Lawrence Heights
# 4                                    Lawrence Manor
# 5                                       Queens Park
# 6                                      Not assigned
# 7                                             Rouge
# 8                                           Malvern
# 9                                   Don Mills North
# 10                                 Woodbine Gardens
# 11                                    Parkview Hill
# 12                                          Ryerson
# 13                                  Garden District
# 14                                        Glencairn
# 15                                       Cloverdale
# 16                                        Islington
# 17                                     Martin Grove
# 18                                 Princess Gardens
# 19                                  West Deane Park
# 20                                   Highland Creek
# 21                                       Rouge Hill
# 22                                       Port Union
# 23                                  Flemingdon Park
# 24                                  Don Mills South
# 25                                 Woodbine Heights
# 26                                    St James Town
# 27                                HumewoodCedarvale
# 28                                Bloordale Gardens
# 29                                         Eringate
# ..                                              ...
# 180                                     Thistletown
# 181                                  LAmoreaux West
# 182                                        Rosedale
# 183                   Stn A PO Boxes  The Esplanade
# 184                                       Alderwood
# 185                                     Long Branch
# 186                                       Northwest
# 187                                     Upper Rouge
# 188                                     Cabbagetown
# 189                                   St James Town
# 190                            First Canadian Place
# 191                                Underground city
# 192                                    The Kingsway
# 193                                 Montgomery Road
# 194                                  Old Mill North
# 195                            Church and Wellesley
# 196  Business Reply Mail Processing Centre  Eastern
# 197                                      Humber Bay
# 198                                 Kings Mill Park
# 199                        Kingsway Park South East
# 200                                       Mimico NE
# 201                                  Old Mill South
# 202                              The Queensway East
# 203                           Royal York South East
# 204                                        Sunnylea
# 205                        Kingsway Park South West
# 206                                       Mimico NW
# 207                              The Queensway West
# 208                           Royal York South West
# 209                                  South of Bloor
#
# [210 rows x 3 columns]

# %% [markdown]
# <h3> This cell groups by Postal Code and Borough (since some codes have multiple boroughs) and then joins the Neighborhoods together using a comma. I then reset the index to make the PostalCode repeat according to how we want the dataframe to look.</h3>

# %%
g = df.reset_index().groupby(['PostalCode', 'Borough'], as_index = False)['Neighborhood'].apply(', '.join)
g = g.to_frame().reset_index()
g.columns = ['PostalCode', 'Borough', 'Neighborhood']
g
# Out:
#    PostalCode           Borough  \
# 0          MA  Downtown Toronto
# 1          MA        North York
# 2          MA       Queens Park
# 3          MB  Downtown Toronto
# 4          MB         East York
# 5          MB         Etobicoke
# 6          MB        North York
# 7          MB       Scarborough
# 8          MC  Downtown Toronto
# 9          MC         East York
# 10         MC         Etobicoke
# 11         MC        North York
# 12         MC       Scarborough
# 13         MC              York
# 14         ME  Downtown Toronto
# 15         ME      East Toronto
# 16         ME       Scarborough
# 17         ME              York
# 18         MG  Downtown Toronto
# 19         MG         East York
# 20         MG       Scarborough
# 21         MH  Downtown Toronto
# 22         MH         East York
# 23         MH        North York
# 24         MH       Scarborough
# 25         MH      West Toronto
# 26         MJ  Downtown Toronto
# 27         MJ         East York
# 28         MJ        North York
# 29         MJ       Scarborough
# ..        ...               ...
# 50         MP        North York
# 51         MP       Scarborough
# 52         MP      West Toronto
# 53         MR   Central Toronto
# 54         MR         Etobicoke
# 55         MR       Mississauga
# 56         MR        North York
# 57         MR       Scarborough
# 58         MR      West Toronto
# 59         MS   Central Toronto
# 60         MS  Downtown Toronto
# 61         MS       Scarborough
# 62         MS      West Toronto
# 63         MT   Central Toronto
# 64         MT  Downtown Toronto
# 65         MT       Scarborough
# 66         MV   Central Toronto
# 67         MV  Downtown Toronto
# 68         MV         Etobicoke
# 69         MV       Scarborough
# 70         MW  Downtown Toronto
# 71         MW         Etobicoke
# 72         MW       Scarborough
# 73         MX  Downtown Toronto
# 74         MX         Etobicoke
# 75         MX       Scarborough
# 76         MY  Downtown Toronto
# 77         MY      East Toronto
# 78         MY         Etobicoke
# 79         MZ         Etobicoke
#
#                                          Neighborhood
# 0                           Harbourfront, Queens Park
# 1   Parkwoods, Victoria Village, Lawrence Heights,...
# 2                                        Not assigned
# 3                            Ryerson, Garden District
# 4                     Woodbine Gardens, Parkview Hill
# 5   Cloverdale, Islington, Martin Grove, Princess ...
# 6                          Don Mills North, Glencairn
# 7                                      Rouge, Malvern
# 8                                       St James Town
# 9                                    Woodbine Heights
# 10  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 11                   Flemingdon Park, Don Mills South
# 12             Highland Creek, Rouge Hill, Port Union
# 13                                  HumewoodCedarvale
# 14                                        Berczy Park
# 15                                        The Beaches
# 16                  Guildwood, Morningside, West Hill
# 17                                 CaledoniaFairbanks
# 18                       Central Bay Street, Christie
# 19                                            Leaside
# 20                                             Woburn
# 21                           Adelaide, King, Richmond
# 22                                   Thorncliffe Park
# 23  Hillcrest Village, Bathurst Manor, Downsview N...
# 24                                          Cedarbrae
# 25                       Dovercourt Village, Dufferin
# 26  Harbourfront East, Toronto Islands, Union Station
# 27                                       East Toronto
# 28  Fairview, Henry Farm, Oriole, Northwood Park, ...
# 29                                Scarborough Village
# ..                                                ...
# 50                                    York Mills West
# 51  Dorset Park, Scarborough Town Centre, Wexford ...
# 52                      High Park, The Junction South
# 53  North Toronto West, The Annex, North Midtown, ...
# 54  Kingsview Village, Martin Grove Gardens, Richv...
# 55              Canada Post Gateway Processing Centre
# 56                                    Willowdale West
# 57                                  Maryvale, Wexford
# 58                             Parkdale, Roncesvalles
# 59                                         Davisville
# 60                     Harbord, University of Toronto
# 61                                          Agincourt
# 62                                 Runnymede, Swansea
# 63                        Moore Park, Summerhill East
# 64          Chinatown, Grange Park, Kensington Market
# 65             Clarks Corners, Sullivan, Tam OShanter
# 66  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 67  CN Tower, Bathurst Quay, Island airport, Harbo...
# 68  Humber Bay Shores, Mimico South, New Toronto, ...
# 69  Agincourt North, LAmoreaux East, Milliken, Ste...
# 70            Rosedale, Stn A PO Boxes  The Esplanade
# 71                  Alderwood, Long Branch, Northwest
# 72                                     LAmoreaux West
# 73  Cabbagetown, St James Town, First Canadian Pla...
# 74      The Kingsway, Montgomery Road, Old Mill North
# 75                                        Upper Rouge
# 76                               Church and Wellesley
# 77     Business Reply Mail Processing Centre  Eastern
# 78  Humber Bay, Kings Mill Park, Kingsway Park Sou...
# 79  Kingsway Park South West, Mimico NW, The Queen...
#
# [80 rows x 3 columns]

# %% [markdown]
# <h3>The code below finds the cell with not assigned neighborhood and assign it to that cells Borough value</h3>

# %%
g.loc[g.Neighborhood == 'Not assigned', 'Neighborhood'] = g.loc[g.Neighborhood == 'Not assigned', 'Borough']
print("There are", len(g.loc[g.Neighborhood == 'Not assigned']), "'not assigned neighborhood' cells")
# Out:
# There are 0 'not assigned neighborhood' cells

# %% [markdown]
# <h3> Final shape answer </h3>

# %%
final_df = g
print("The shape of the fully pre-processed dataframe is: ", final_df.shape)
# Out:
# The shape of the fully pre-processed dataframe is:  (80, 3)
